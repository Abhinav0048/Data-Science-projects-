# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
train=pd.read_csv("~/Downloads/train-2.csv")
test=pd.read_csv("~/Downloads/test-2.csv")

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
combine=pd.concat([train,test],ignore_index=False,sort=False)

# %%
combine
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
combine.isnull().sum()/len(combine) # Percentage of missing data in the combine data
# Out:
# User_ID                       0.000000
# Product_ID                    0.000000
# Gender                        0.000000
# Age                           0.000000
# Occupation                    0.000000
# City_Category                 0.000000
# Stay_In_Current_City_Years    0.000000
# Marital_Status                0.000000
# Product_Category_1            0.000000
# Product_Category_2            0.313886
# Product_Category_3            0.696481
# Purchase                      0.298085
# dtype: float64

# %%
combine.shape
# Out:
# (783667, 12)

# %%
combine.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
combine.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023976        0.020276            0.004568
# Occupation         -0.023976    1.000000        0.023563           -0.008441
# Marital_Status      0.020276    0.023563        1.000000            0.019579
# Product_Category_1  0.004568   -0.008441        0.019579            1.000000
# Product_Category_2  0.002291   -0.000773        0.017131            0.540426
# Product_Category_3  0.002490    0.010450        0.018471            0.228299
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.002291            0.002490  0.004716
# Occupation                   -0.000773            0.010450  0.020833
# Marital_Status                0.017131            0.018471 -0.000463
# Product_Category_1            0.540426            0.228299 -0.343703
# ...

# %%
combine
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
combine.Product_Category_1.isnull().sum()
# Out:
# 0

# %%
combine.Product_Category_2.isnull().sum()
# Out:
# 245982

# %%
combine.Product_Category_3.isnull().sum()
# Out:
# 545809

# %%
combine.Product_Category_3.unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
combine.drop(['User_ID','Product_ID'],axis=1,inplace=True)

# %%
combine
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 233594      F  26-35          15             B                         4+
# 233595      F  26-35          15             B                         4+
# 233596      F  26-35          15             B                         4+
# 233597      F  46-50           1             C                         4+
# 233598      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
combine['Gender']=combine['Gender'].replace({'F':0,'M':1})

# %%
combine.dtypes
# Out:
# Gender                          int64
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
combine
# Out:
#         Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            0   0-17          10             A                          2
# 1            0   0-17          10             A                          2
# 2            0   0-17          10             A                          2
# 3            0   0-17          10             A                          2
# 4            1    55+          16             C                         4+
# ...        ...    ...         ...           ...                        ...
# 233594       0  26-35          15             B                         4+
# 233595       0  26-35          15             B                         4+
# 233596       0  26-35          15             B                         4+
# 233597       0  46-50           1             C                         4+
# 233598       0  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
combine.City_Category.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
combine.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
def age(x):
    if x=='0-17':
        return 'young'
    elif x=='55+' or x=='51-55':
        return 'old'
    elif x=='18-25':
        return 'adult'
    else:
        return 'middle-age'

# %%
combine.Age=combine.Age.apply(age)

# %%
combine
# Out:
#         Gender         Age  Occupation City_Category  \
# 0            0       young          10             A
# 1            0       young          10             A
# 2            0       young          10             A
# 3            0       young          10             A
# 4            1         old          16             C
# ...        ...         ...         ...           ...
# 233594       0  middle-age          15             B
# 233595       0  middle-age          15             B
# 233596       0  middle-age          15             B
# 233597       0  middle-age           1             C
# 233598       0  middle-age           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# ...

# %%
dummydata=pd.get_dummies(combine, drop_first=True)

# %%
dummydata
# Out:
#         Gender  Occupation  Marital_Status  Product_Category_1  \
# 0            0          10               0                   3
# 1            0          10               0                   1
# 2            0          10               0                  12
# 3            0          10               0                  12
# 4            1          16               0                   8
# ...        ...         ...             ...                 ...
# 233594       0          15               1                   8
# 233595       0          15               1                   5
# 233596       0          15               1                   1
# 233597       0           1               0                  10
# 233598       0           0               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase  Age_middle-age  \
# 0                      NaN                 NaN    8370.0               0
# ...

# %%
dummydata.isnull().sum()
# Out:
# Gender                                0
# Occupation                            0
# Marital_Status                        0
# Product_Category_1                    0
# Product_Category_2               245982
# Product_Category_3               545809
# Purchase                         233599
# Age_middle-age                        0
# Age_old                               0
# Age_young                             0
# City_Category_B                       0
# City_Category_C                       0
# Stay_In_Current_City_Years_1          0
# Stay_In_Current_City_Years_2          0
# Stay_In_Current_City_Years_3          0
# Stay_In_Current_City_Years_4+         0
# dtype: int64

# %%
final=dummydata.loc[~(dummydata.Purchase.isnull())]

# %%
final.isnull().sum()
# Out:
# Gender                                0
# Occupation                            0
# Marital_Status                        0
# Product_Category_1                    0
# Product_Category_2               173638
# Product_Category_3               383247
# Purchase                              0
# Age_middle-age                        0
# Age_old                               0
# Age_young                             0
# City_Category_B                       0
# City_Category_C                       0
# Stay_In_Current_City_Years_1          0
# Stay_In_Current_City_Years_2          0
# Stay_In_Current_City_Years_3          0
# Stay_In_Current_City_Years_4+         0
# dtype: int64

# %%
final.loc[final.Product_Category_3.isnull(),]
# Out:
#         Gender  Occupation  Marital_Status  Product_Category_1  \
# 0            0          10               0                   3
# 2            0          10               0                  12
# 3            0          10               0                  12
# 4            1          16               0                   8
# 5            1          15               0                   1
# ...        ...         ...             ...                 ...
# 550063       1          13               1                  20
# 550064       0           1               0                  20
# 550065       0          15               1                  20
# 550066       0           1               0                  20
# 550067       0           0               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  Age_middle-age  \
# 0                      NaN                 NaN    8370.0               0
# ...

# %%
final['Product_Category_3']=final['Product_Category_3'].fillna(0)
# Out:
# /var/folders/3_/v3zxr5qs2132z44ltsvfwrb80000gn/T/ipykernel_1819/1117281877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Product_Category_3']=final['Product_Category_3'].fillna(0)

# %%
final.isnull().sum()
# Out:
# Gender                                0
# Occupation                            0
# Marital_Status                        0
# Product_Category_1                    0
# Product_Category_2               173638
# Product_Category_3                    0
# Purchase                              0
# Age_middle-age                        0
# Age_old                               0
# Age_young                             0
# City_Category_B                       0
# City_Category_C                       0
# Stay_In_Current_City_Years_1          0
# Stay_In_Current_City_Years_2          0
# Stay_In_Current_City_Years_3          0
# Stay_In_Current_City_Years_4+         0
# dtype: int64

# %%
final['Product_Category_2']=final['Product_Category_2'].fillna(0)
# Out:
# /var/folders/3_/v3zxr5qs2132z44ltsvfwrb80000gn/T/ipykernel_1819/1331748801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Product_Category_2']=final['Product_Category_2'].fillna(0)

# %%
final.columns
# Out:
# Index(['Gender', 'Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase',
#        'Age_middle-age', 'Age_old', 'Age_young', 'City_Category_B',
#        'City_Category_C', 'Stay_In_Current_City_Years_1',
#        'Stay_In_Current_City_Years_2', 'Stay_In_Current_City_Years_3',
#        'Stay_In_Current_City_Years_4+'],
#       dtype='object')

# %%
cols=['Gender', 'Occupation', 'Marital_Status', 'Product_Category_1',
       'Product_Category_2', 'Product_Category_3',
       'Age_middle-age', 'Age_old', 'Age_young', 'City_Category_B',
       'City_Category_C', 'Stay_In_Current_City_Years_1',
       'Stay_In_Current_City_Years_2', 'Stay_In_Current_City_Years_3',
       'Stay_In_Current_City_Years_4+']
x=final[cols]
y=final['Purchase']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1)

# %% [markdown]
# # Simple Linear Regression

# %%
xtrain=22
# Out:
#         Gender  Occupation  Marital_Status  Product_Category_1  \
# 396797       1           6               0                   8
# 316599       1          12               1                   5
# 428580       1           1               1                   5
# 387279       1          20               0                   8
# 421397       1           7               0                   5
# ...        ...         ...             ...                 ...
# 371403       0           7               0                   8
# 491263       0           1               0                   1
# 470924       0           9               0                   5
# 491755       1           0               0                   5
# 128037       0           4               0                   8
#
#         Product_Category_2  Product_Category_3  Age_middle-age  Age_old  \
# 396797                 0.0                 0.0               0        0
# ...
