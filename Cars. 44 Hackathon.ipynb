# %% [markdown]
# # Data Dictionary
# * Name: Name of the Car (Brand & Model mentioned)
# * Location: Location where the Car was sold/is available for purchase.
# * Year: Year of the Car Built
# * Kilometers_Driven: The total number of Kilometers driven by the Previous Owner.
# * Fuel Type: Either is Petrol, Diesel, or CNG Car.
# * Transmission: Manual or Automatic
# * Owner_Type: Either it is the First Owner car or the Second Owner or Other.
# * Mileage: Mileage Offered by the Car Manufacturer.
# * Engine: Engine Capacity in CC
# * Power: Power generated by the car engine in bhp
# * Seats: Number of Seats in the Car
# * New_Price: The price of a new car of the same model.
# * Price: target variable

# %%
import numpy as np
import pandas as pd 
import os 
os.chdir('/Users/Abhi/Downloads/')
pd.set_option('display.max_columns', None)

train=pd.read_csv('Train_cars.csv')
test=pd.read_csv('Test_cars.csv')

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train.head()
# Out:
#                       Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII   Bangalore  2012              33715    Diesel
# 1      Honda City 1.5 V AT       Delhi  2013              73977    Diesel
# 2        Honda CR-V RVi MT       Delhi  2007              16460       CNG
# 3  Skoda Yeti Ambition 4X2     Kolkata  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG  Coimbatore  2013              41656    Petrol
#
#   Transmission Owner_Type     Mileage   Engine     Power  Seats   New_Price  \
# 0       Manual      First  16.46 kmpl  1248 CC   100 bhp    5.0  43.65 Lakh
# 1       Manual      First   18.6 kmpl  2993 CC    61 bhp    4.0         NaN
# 2       Manual      Third   15.3 kmpl  1599 CC   140 bhp    5.0         NaN
# 3       Manual      First  25.47 kmpl  1196 CC  86.8 bhp    5.0         NaN
# 4    Automatic      First  19.12 kmpl  1999 CC   115 bhp    7.0  13.26 Lakh
#
#    Price
# 0  25.53
# 1   4.58
# 2   2.37
# 3   1.20
# 4  33.04

# %%
comb=pd.concat([train,test])

# %%
comb.head()
# Out:
#                       Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII   Bangalore  2012              33715    Diesel
# 1      Honda City 1.5 V AT       Delhi  2013              73977    Diesel
# 2        Honda CR-V RVi MT       Delhi  2007              16460       CNG
# 3  Skoda Yeti Ambition 4X2     Kolkata  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG  Coimbatore  2013              41656    Petrol
#
#   Transmission Owner_Type     Mileage   Engine     Power  Seats   New_Price  \
# 0       Manual      First  16.46 kmpl  1248 CC   100 bhp    5.0  43.65 Lakh
# 1       Manual      First   18.6 kmpl  2993 CC    61 bhp    4.0         NaN
# 2       Manual      Third   15.3 kmpl  1599 CC   140 bhp    5.0         NaN
# 3       Manual      First  25.47 kmpl  1196 CC  86.8 bhp    5.0         NaN
# 4    Automatic      First  19.12 kmpl  1999 CC   115 bhp    7.0  13.26 Lakh
#
#    Price
# 0  25.53
# 1   4.58
# 2   2.37
# 3   1.20
# 4  33.04

# %%
comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75000 entries, 0 to 52499
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               75000 non-null  object
#  1   Location           75000 non-null  object
#  2   Year               75000 non-null  int64
#  3   Kilometers_Driven  75000 non-null  int64
#  4   Fuel_Type          75000 non-null  object
#  5   Transmission       75000 non-null  object
#  6   Owner_Type         75000 non-null  object
#  7   Mileage            74659 non-null  object
#  8   Engine             74894 non-null  object
#  9   Power              74683 non-null  object
#  10  Seats              74662 non-null  float64
#  11  New_Price          13066 non-null  object
#  12  Price              22500 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 8.0+ MB

# %%
comb.Location.value_counts()
# Out:
# Mumbai        14432
# Hyderabad     12869
# Kolkata       11531
# Chennai        7829
# Jaipur         5914
# Delhi          4934
# Bangalore      4374
# Kochi          3724
# Coimbatore     3602
# Pune           3432
# Ahmedabad      2359
# Name: Location, dtype: int64

# %%
east=['Kolkata']
north=['Delhi','Ahmedabad','Jaipur']
west=['Pune','Mumbai']
south=['Banglore','Chennai','Hyderabad','Coimbatore','Kochi']

# %%
def region(x):
    if x in north:
        return ('North')
    elif x in west:
        return('West')
    elif x in south:
        return('South')
    else:
        return('East')

# %%
comb['Location']=comb.Location.apply(region)

# %%
comb.Location.value_counts()
# Out:
# South    28024
# West     17864
# East     15905
# North    13207
# Name: Location, dtype: int64

# %%
comb.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
#creating new feature from year

# %%
comb['Year_old']=2022-comb['Year']

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460       CNG
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission Owner_Type     Mileage   Engine     Power  Seats   New_Price  \
# 0       Manual      First  16.46 kmpl  1248 CC   100 bhp    5.0  43.65 Lakh
# 1       Manual      First   18.6 kmpl  2993 CC    61 bhp    4.0         NaN
# 2       Manual      Third   15.3 kmpl  1599 CC   140 bhp    5.0         NaN
# 3       Manual      First  25.47 kmpl  1196 CC  86.8 bhp    5.0         NaN
# 4    Automatic      First  19.12 kmpl  1999 CC   115 bhp    7.0  13.26 Lakh
#
#    Price  Year_old
# 0  25.53        10
# 1   4.58         9
# 2   2.37        15
# ...

# %%
comb.Fuel_Type.value_counts()
# Out:
# Petrol      33678
# Diesel      33567
# CNG          7648
# LPG            57
# Electric       50
# Name: Fuel_Type, dtype: int64

# %%
def fuel(x):
    if x=='Petrol':
        return 'Petrol'
    elif x=='Diesel':
        return 'Diesel'
    else:
        return 'Other'

# %%
comb['Fuel_Type']=comb.Fuel_Type.apply(fuel)

# %%
comb.Fuel_Type.value_counts()
# Out:
# Petrol    33678
# Diesel    33567
# Other      7755
# Name: Fuel_Type, dtype: int64

# %%
comb.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Year_old'],
#       dtype='object')

# %%
comb.Transmission.value_counts()
# Out:
# Manual       60107
# Automatic    14893
# Name: Transmission, dtype: int64

# %%
comb.Owner_Type.value_counts()
# Out:
# First             67452
# Second             5647
# Third              1736
# Fourth & Above      165
# Name: Owner_Type, dtype: int64

# %%
def owner(x):
    if x=='First':
        return 'First'
    elif x=='Second':
        return 'Second'
    else:
        return 'Third & Above'

# %%
comb['Owner_Type']=comb.Owner_Type.apply(owner)

# %%
comb.Owner_Type.value_counts()
# Out:
# First            67452
# Second            5647
# Third & Above     1901
# Name: Owner_Type, dtype: int64

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460     Other
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission     Owner_Type     Mileage   Engine     Power  Seats  \
# 0       Manual          First  16.46 kmpl  1248 CC   100 bhp    5.0
# 1       Manual          First   18.6 kmpl  2993 CC    61 bhp    4.0
# 2       Manual  Third & Above   15.3 kmpl  1599 CC   140 bhp    5.0
# 3       Manual          First  25.47 kmpl  1196 CC  86.8 bhp    5.0
# 4    Automatic          First  19.12 kmpl  1999 CC   115 bhp    7.0
#
#     New_Price  Price  Year_old
# 0  43.65 Lakh  25.53        10
# 1         NaN   4.58         9
# 2         NaN   2.37        15
# ...

# %%
comb.Mileage.value_counts()
# Out:
# 26.6 km/kg    4212
# 17.0 kmpl     1990
# 12.8 kmpl     1952
# 17.8 kmpl     1511
# 22.32 kmpl     876
#               ...
# 21.2 kmpl       14
# 14.81 kmpl      14
# 11.78 kmpl      12
# 18.18 kmpl      11
# 17.24 kmpl      10
# Name: Mileage, Length: 442, dtype: int64

# %%
comb['Mileage'].str.split(' ').str[0]
# Out:
# 0        16.46
# 1         18.6
# 2         15.3
# 3        25.47
# 4        19.12
#          ...
# 52495    16.09
# 52496     12.6
# 52497     22.0
# 52498    10.98
# 52499     14.0
# Name: Mileage, Length: 75000, dtype: object

# %%
comb['Mileage']=comb['Mileage'].str.split(' ').str[0]

# %%
comb['Mileage']=comb['Mileage'].astype(float)

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460     Other
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission     Owner_Type  Mileage   Engine     Power  Seats   New_Price  \
# 0       Manual          First    16.46  1248 CC   100 bhp    5.0  43.65 Lakh
# 1       Manual          First    18.60  2993 CC    61 bhp    4.0         NaN
# 2       Manual  Third & Above    15.30  1599 CC   140 bhp    5.0         NaN
# 3       Manual          First    25.47  1196 CC  86.8 bhp    5.0         NaN
# 4    Automatic          First    19.12  1999 CC   115 bhp    7.0  13.26 Lakh
#
#    Price  Year_old
# 0  25.53        10
# 1   4.58         9
# ...

# %%
comb['Power']=comb['Power'].str.split(' ').str[0]

# %%
comb.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# Year_old               int64
# dtype: object

# %%
comb['Power'].value_counts()
# Out:
# 58.16     4550
# 67.1      3014
# null      2316
# 121.3     1604
# 70        1549
#           ...
# 52.8        16
# 74.93       16
# 73.74       15
# 254         12
# 181.04       7
# Name: Power, Length: 372, dtype: int64

# %%
comb['Power'].mode()
# Out:
# 0    58.16
# dtype: object

# %%
comb['Power']=comb['Power'].replace(to_replace='null',value='58.16')

# %%
comb['Power']=comb['Power'].astype(float)

# %%
comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75000 entries, 0 to 52499
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               75000 non-null  object
#  1   Location           75000 non-null  object
#  2   Year               75000 non-null  int64
#  3   Kilometers_Driven  75000 non-null  int64
#  4   Fuel_Type          75000 non-null  object
#  5   Transmission       75000 non-null  object
#  6   Owner_Type         75000 non-null  object
#  7   Mileage            74659 non-null  float64
#  8   Engine             74894 non-null  object
#  9   Power              74683 non-null  float64
#  10  Seats              74662 non-null  float64
#  11  New_Price          13066 non-null  object
#  12  Price              22500 non-null  float64
#  13  Year_old           75000 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 8.6+ MB

# %%
comb.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Year_old'],
#       dtype='object')

# %%
comb['Seats'].value_counts()
# Out:
# 5.0    61356
# 7.0     9535
# 8.0     2654
# 4.0      777
# 6.0      340
# Name: Seats, dtype: int64

# %%
# Creating new feature from the Name

# %%
comb.Name.value_counts()
# Out:
# Maruti Wagon R LXI CNG                                  449
# Honda City 1.5 S MT                                     430
# Maruti Swift VDI                                        415
# Hyundai i10 Sportz                                      374
# BMW 3 Series 320d                                       370
#                                                        ...
# Mercedes-Benz New C-Class C 200 Avantgarde Edition C      1
# Volkswagen Ameo 1.2 MPI Highline Plus 16                  1
# Mercedes-Benz GLA Class 200 d Style                       1
# Hyundai i20 Active S Diesel                               1
# Maruti Ertiga VDI Limited Edition                         1
# Name: Name, Length: 1515, dtype: int64

# %%
comb.Name.str.split(' ').str[0]
# Out:
# 0         Maruti
# 1          Honda
# 2          Honda
# 3          Skoda
# 4        Hyundai
#           ...
# 52495      Honda
# 52496     Toyota
# 52497     Maruti
# 52498     Toyota
# 52499     Toyota
# Name: Name, Length: 75000, dtype: object

# %%
comb['Manfacturer']=comb.Name.str.split(' ').str[0]

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460     Other
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission     Owner_Type  Mileage   Engine  Power  Seats   New_Price  \
# 0       Manual          First    16.46  1248 CC  100.0    5.0  43.65 Lakh
# 1       Manual          First    18.60  2993 CC   61.0    4.0         NaN
# 2       Manual  Third & Above    15.30  1599 CC  140.0    5.0         NaN
# 3       Manual          First    25.47  1196 CC   86.8    5.0         NaN
# 4    Automatic          First    19.12  1999 CC  115.0    7.0  13.26 Lakh
#
#    Price  Year_old Manfacturer
# 0  25.53        10      Maruti
# ...

# %%
comb['Manfacturer'].value_counts()
# Out:
# Maruti           15405
# Hyundai          12491
# Honda             7007
# Toyota            6152
# Mercedes-Benz     4551
# BMW               3840
# Volkswagen        3614
# Ford              3503
# Audi              3385
# Mahindra          2242
# Tata              2176
# Skoda             1886
# Renault           1760
# Chevrolet         1687
# Land               939
# Nissan             897
# Fiat               595
# Jaguar             530
# Mini               454
# Jeep               439
# Mitsubishi         403
# Volvo              329
# Datsun             284
# Porsche            231
# ISUZU               73
# Isuzu               69
# Force               55
# Bentley              3
# Name: Manfacturer, dtype: int64

# %%
comb.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Year_old', 'Manfacturer'],
#       dtype='object')

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460     Other
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission     Owner_Type  Mileage   Engine  Power  Seats   New_Price  \
# 0       Manual          First    16.46  1248 CC  100.0    5.0  43.65 Lakh
# 1       Manual          First    18.60  2993 CC   61.0    4.0         NaN
# 2       Manual  Third & Above    15.30  1599 CC  140.0    5.0         NaN
# 3       Manual          First    25.47  1196 CC   86.8    5.0         NaN
# 4    Automatic          First    19.12  1999 CC  115.0    7.0  13.26 Lakh
#
#    Price  Year_old Manfacturer
# 0  25.53        10      Maruti
# ...

# %%
comb['Engine']=comb.Engine.str.split(' ').str[0]

# %%
comb['Engine']=comb['Engine'].astype(float)

# %%
comb['New_Price']=comb.New_Price.str.split(' ').str[0]

# %%
comb['New_Price']=comb['New_Price'].astype(float)

# %%
comb.head(100)
# Out:
#                                               Name Location  Year  \
# 0                             Maruti 800 Std BSIII     East  2012
# 1                              Honda City 1.5 V AT    North  2013
# 2                                Honda CR-V RVi MT    North  2007
# 3                          Skoda Yeti Ambition 4X2     East  2009
# 4                            Hyundai i10 Magna LPG    South  2013
# ..                                             ...      ...   ...
# 95  Volkswagen Jetta 2007-2011 2.0 TDI Comfortline    South  2014
# 96       Mercedes-Benz New C-Class C250 Avantgarde     East  2013
# 97                     BMW 5 Series 2003-2012 520d     West  2007
# 98                                  Maruti SX4 ZDI    South  2010
# 99                     BMW 7 Series 730Ld Eminence    South  2006
#
#     Kilometers_Driven Fuel_Type Transmission     Owner_Type  Mileage  Engine  \
# 0               33715    Diesel       Manual          First    16.46  1248.0
# ...

# %%
# Treating Missing Values

# %%
comb.isnull().sum()
# Out:
# Name                     0
# Location                 0
# Year                     0
# Kilometers_Driven        0
# Fuel_Type                0
# Transmission             0
# Owner_Type               0
# Mileage                341
# Engine                 106
# Power                  317
# Seats                  338
# New_Price            61934
# Price                52500
# Year_old                 0
# Manfacturer              0
# dtype: int64

# %%
comb.Mileage.median()
# Out:
# 17.8

# %%
comb['Mileage']=comb.Mileage.fillna(comb.Mileage.median())

# %%
comb['Engine']=comb.Engine.fillna(comb.Engine.median())
comb['Power']=comb.Power.fillna(comb.Power.median())

# %%
comb['Seats']=comb.Seats.fillna(comb.Seats.median())

# %%
comb.isnull().sum()
# Out:
# Name                     0
# Location                 0
# Year                     0
# Kilometers_Driven        0
# Fuel_Type                0
# Transmission             0
# Owner_Type               0
# Mileage                  0
# Engine                   0
# Power                    0
# Seats                    0
# New_Price            61934
# Price                52500
# Year_old                 0
# Manfacturer              0
# dtype: int64

# %%
comb=comb.drop('New_Price',axis=1)

# %%
comb.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price', 'Year_old', 'Manfacturer'],
#       dtype='object')

# %%
comb.head()
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti 800 Std BSIII     East  2012              33715    Diesel
# 1      Honda City 1.5 V AT    North  2013              73977    Diesel
# 2        Honda CR-V RVi MT    North  2007              16460     Other
# 3  Skoda Yeti Ambition 4X2     East  2009              35048    Petrol
# 4    Hyundai i10 Magna LPG    South  2013              41656    Petrol
#
#   Transmission     Owner_Type  Mileage  Engine  Power  Seats  Price  Year_old  \
# 0       Manual          First    16.46  1248.0  100.0    5.0  25.53        10
# 1       Manual          First    18.60  2993.0   61.0    4.0   4.58         9
# 2       Manual  Third & Above    15.30  1599.0  140.0    5.0   2.37        15
# 3       Manual          First    25.47  1196.0   86.8    5.0   1.20        13
# 4    Automatic          First    19.12  1999.0  115.0    7.0  33.04         9
#
#   Manfacturer
# 0      Maruti
# 1       Honda
# 2       Honda
# ...

# %%
comb['fueleconomy'] = (0.55 * comb['Mileage'])

# %%
comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75000 entries, 0 to 52499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               75000 non-null  object
#  1   Location           75000 non-null  object
#  2   Year               75000 non-null  int64
#  3   Kilometers_Driven  75000 non-null  int64
#  4   Fuel_Type          75000 non-null  object
#  5   Transmission       75000 non-null  object
#  6   Owner_Type         75000 non-null  object
#  7   Mileage            75000 non-null  float64
#  8   Engine             75000 non-null  float64
#  9   Power              75000 non-null  float64
#  10  Seats              75000 non-null  float64
#  11  Price              22500 non-null  float64
#  12  Year_old           75000 non-null  int64
#  13  Manfacturer        75000 non-null  object
#  14  fueleconomy        75000 non-null  float64
# dtypes: float64(6), int64(3), object(6)
# ...

# %%
comb=comb.drop('Name',axis=1)

# %%
#comb=comb.drop('Location',axis=1)

# %%
comb.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price',
#        'Year_old', 'Manfacturer', 'fueleconomy'],
#       dtype='object')

# %%
final=pd.get_dummies(comb,drop_first=True)

# %%
final.shape
# Out:
# (75000, 44)

# %%
newtrain=final.iloc[0:train.shape[0],:]
newtest=final.iloc[train.shape[0]:,:]

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=newtrain.drop('Price',axis=1)
y=newtrain['Price']

# %%
X=newtrain.drop('Price',axis=1)
Y=newtrain['Price']

# %%
newtest=newtest.drop('Price',axis=1)

# %%
newtest.shape
# Out:
# (52500, 43)

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)
newtest1=pd.DataFrame(sc.transform(newtest),columns=newtest.columns)

# %%
x.head()

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
import statsmodels.api as sm

# %%
x_c=sm.add_constant(x)
newtest1_c=sm.add_constant(newtest1)
# Out:
# /Users/abhi/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lr=sm.OLS(y,x1).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.108
# Model:                            OLS   Adj. R-squared (uncentered):              0.107
# Method:                 Least Squares   F-statistic:                              71.79
# Date:                Sat, 01 Oct 2022   Prob (F-statistic):                        0.00
# Time:                        18:00:02   Log-Likelihood:                         -81721.
# No. Observations:               22500   AIC:                                  1.635e+05
# Df Residuals:                   22462   BIC:                                  1.638e+05
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
rf=RandomForestRegressor(n_estimators=350,max_depth=12)
model1=rf.fit(x,y).predict(newtest1)

# %%
submission=pd.DataFrame({'Name':test.Name,'Price':model10})

submission=submission.set_index('Name')

submission.to_csv('Cars_price_1.csv')

# %%
rf=RandomForestRegressor(n_estimators=350,max_depth=12)
model10=rf.fit(x,y).predict(newtest1)

# %%
fe=rf.fit(x,y)

# %%
plt.figure(figsize=(40,35))
plt.barh(x.columns, fe.feature_importances_)
# Out:
# <BarContainer object of 43 artists>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = x1.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(x1.values, i)
                          for i in range(len(x1.columns))]
  
print(vif_data)
# Out:
# /Users/abhi/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#                       feature       VIF
# 0           Kilometers_Driven  1.104102
# 1                      Engine  1.104497
# 2                       Power  1.047274
# 3                       Seats  1.095505
# 4              Location_North  1.555272
# 5              Location_South  1.755060
# 6               Location_West  1.608854
# 7             Fuel_Type_Other  1.244219
# 8            Fuel_Type_Petrol  1.293377
# 9         Transmission_Manual  1.112561
# 10          Owner_Type_Second  1.056521
# 11   Owner_Type_Third & Above  1.063749
# 12            Manfacturer_BMW  2.034030
# 13        Manfacturer_Bentley       NaN
# 14      Manfacturer_Chevrolet  1.489048
# 15         Manfacturer_Datsun  1.080018
# 16           Manfacturer_Fiat  1.166972
# ...

# %%
x.columns
# Out:
# Index(['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Year_old', 'fueleconomy', 'Location_North', 'Location_South',
#        'Location_West', 'Fuel_Type_Other', 'Fuel_Type_Petrol',
#        'Transmission_Manual', 'Owner_Type_Second', 'Owner_Type_Third & Above',
#        'Manfacturer_BMW', 'Manfacturer_Bentley', 'Manfacturer_Chevrolet',
#        'Manfacturer_Datsun', 'Manfacturer_Fiat', 'Manfacturer_Force',
#        'Manfacturer_Ford', 'Manfacturer_Honda', 'Manfacturer_Hyundai',
#        'Manfacturer_ISUZU', 'Manfacturer_Isuzu', 'Manfacturer_Jaguar',
#        'Manfacturer_Jeep', 'Manfacturer_Land', 'Manfacturer_Mahindra',
#        'Manfacturer_Maruti', 'Manfacturer_Mercedes-Benz', 'Manfacturer_Mini',
#        'Manfacturer_Mitsubishi', 'Manfacturer_Nissan', 'Manfacturer_Porsche',
#        'Manfacturer_Renault', 'Manfacturer_Skoda', 'Manfacturer_Tata',
#        'Manfacturer_Toyota', 'Manfacturer_Volkswagen', 'Manfacturer_Volvo'],
#       dtype='object')

# %%
x1=x_c[[ 'Kilometers_Driven', 'Engine', 'Power', 'Seats',
         'Location_North', 'Location_South',
       'Location_West', 'Fuel_Type_Other', 'Fuel_Type_Petrol',
       'Transmission_Manual', 'Owner_Type_Second', 'Owner_Type_Third & Above',
       'Manfacturer_BMW', 'Manfacturer_Bentley', 'Manfacturer_Chevrolet',
       'Manfacturer_Datsun', 'Manfacturer_Fiat', 'Manfacturer_Force',
       'Manfacturer_Ford', 'Manfacturer_Honda', 'Manfacturer_Hyundai',
       'Manfacturer_ISUZU', 'Manfacturer_Isuzu', 'Manfacturer_Jaguar',
       'Manfacturer_Jeep', 'Manfacturer_Land', 'Manfacturer_Mahindra',
       'Manfacturer_Maruti', 'Manfacturer_Mercedes-Benz', 'Manfacturer_Mini',
       'Manfacturer_Mitsubishi', 'Manfacturer_Nissan', 'Manfacturer_Porsche',
       'Manfacturer_Renault', 'Manfacturer_Skoda', 'Manfacturer_Tata',
       'Manfacturer_Toyota', 'Manfacturer_Volkswagen', 'Manfacturer_Volvo']]

# %%
newtest2=newtest1_c[['Kilometers_Driven', 'Engine', 'Power', 'Seats',
         'Location_North', 'Location_South',
       'Location_West', 'Fuel_Type_Other', 'Fuel_Type_Petrol',
       'Transmission_Manual', 'Owner_Type_Second', 'Owner_Type_Third & Above',
       'Manfacturer_BMW', 'Manfacturer_Bentley', 'Manfacturer_Chevrolet',
       'Manfacturer_Datsun', 'Manfacturer_Fiat', 'Manfacturer_Force',
       'Manfacturer_Ford', 'Manfacturer_Honda', 'Manfacturer_Hyundai',
       'Manfacturer_ISUZU', 'Manfacturer_Isuzu', 'Manfacturer_Jaguar',
       'Manfacturer_Jeep', 'Manfacturer_Land', 'Manfacturer_Mahindra',
       'Manfacturer_Maruti', 'Manfacturer_Mercedes-Benz', 'Manfacturer_Mini',
       'Manfacturer_Mitsubishi', 'Manfacturer_Nissan', 'Manfacturer_Porsche',
       'Manfacturer_Renault', 'Manfacturer_Skoda', 'Manfacturer_Tata',
       'Manfacturer_Toyota', 'Manfacturer_Volkswagen', 'Manfacturer_Volvo']]

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm, 10)
rfe = rfe.fit(x, y)
list(zip(X.columns,rfe.support_,rfe.ranking_))

# %%
x.columns[rfe.support_]

# %%
 x_rfe= X_train[x.columns[rfe.support_]]
X_train_rfe.head()

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.ensemble import StackingRegressor

level_0 =[("rf",rf),("gbm",gbm),("lgbm",lgbm)]

stack= StackingRegressor(estimators=level_0, final_estimator=rf)
model13=stack.fit(x,y).predict(newtest)
